# %%
import numpy as np
import pandas as pd
recordsIn = pd.read_csv('Stray_Cat_Dog_2018.csv', encoding='latin-1')

# %%
testAPI = recordsIn
testAPI
# Out:
#        Unnamed: 0 Animal ID          Name             DateTime  \
# 0              13   A773634         Augie  2018-06-03 15:26:00
# 1              19   A782291           NaN  2018-10-13 10:59:00
# 2              23   A782085          Luna  2018-10-10 13:21:00
# 3              38   A783925           NaN  2018-11-08 17:56:00
# 4              46   A768476       *Fialla  2018-03-20 10:57:00
# 5              48   A776610          Ruby  2018-07-16 15:33:00
# 6              63   A777688         *Rook  2018-08-01 13:11:00
# 7              75   A765493   *Milk Shake  2018-01-21 12:33:00
# 8              81   A773687  *Joan Cusack  2018-06-04 12:48:00
# 9              97   A711096       Schatzi  2018-07-26 12:46:00
# 10            104   A782729        *Remus  2018-10-20 12:24:00
# 11            108   A783151           NaN  2018-10-26 08:11:00
# 12            115   A780724           NaN  2018-09-19 13:36:00
# 13            118   A780913           NaN  2018-09-21 18:47:00
# ...

# %%
new = testAPI["Found Location"].str.split(" in ", n = 1, expand = True)
new1 = new[1].str.split("(", n = 1, expand = True)
new1[1] = new1[1].str.replace(")", '')
testAPI["Address"] = new[0]
testAPI["City"] = new1[0]
testAPI["State"] = new1[1]
testAPI.drop(columns =["Found Location"], inplace = True)

testAPI
# Out:
#        Unnamed: 0 Animal ID          Name             DateTime  \
# 0              13   A773634         Augie  2018-06-03 15:26:00
# 1              19   A782291           NaN  2018-10-13 10:59:00
# 2              23   A782085          Luna  2018-10-10 13:21:00
# 3              38   A783925           NaN  2018-11-08 17:56:00
# 4              46   A768476       *Fialla  2018-03-20 10:57:00
# 5              48   A776610          Ruby  2018-07-16 15:33:00
# 6              63   A777688         *Rook  2018-08-01 13:11:00
# 7              75   A765493   *Milk Shake  2018-01-21 12:33:00
# 8              81   A773687  *Joan Cusack  2018-06-04 12:48:00
# 9              97   A711096       Schatzi  2018-07-26 12:46:00
# 10            104   A782729        *Remus  2018-10-20 12:24:00
# 11            108   A783151           NaN  2018-10-26 08:11:00
# 12            115   A780724           NaN  2018-09-19 13:36:00
# 13            118   A780913           NaN  2018-09-21 18:47:00
# ...

# %%
testAPI.shape
# Out:
# (11210, 15)

# %%
import geocoder
import folium
from geopy.geocoders import GoogleV3
from geopy import geocoders
geolocator = GoogleV3(api_key="AIzaSyBmJkT-Ytt6zPAmD-wpSzwxX6u2u3477I0")
g = geocoders.GoogleV3(api_key="AIzaSyBmJkT-Ytt6zPAmD-wpSzwxX6u2u3477I0")

# %%
coord = pd.DataFrame([])
for i, row in testAPI.iterrows():
    location = str(row['Address'] + " " + row["City"] + " " + row["State"])
    result = g.geocode(location)
    Latitude = float(result.latitude)
    Longitude =float(result.longitude)
    line = pd.Series([location, Latitude, Longitude])
    coord = coord.append(line, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-679c5a9e9273> in <module>
#       3     location = str(row['Address'] + " " + row["City"] + " " + row["State"])
#       4     result = g.geocode(location)
# ----> 5     Latitude = float(result.latitude)
#       6     Longitude =float(result.longitude)
#       7     line = pd.Series([location, Latitude, Longitude])
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
coord.tail()
# Out:
#                                                       0          1          2
# 3808  North Lamar Boulevard And West Parmer Lane Aus...  30.407912 -97.678213
# 3809                     6201 Softwood Drive Austin  TX  30.185749 -97.748397
# 3810                        Bolm And Mansell Austin  TX  30.261123 -97.696092
# 3811                        9219 Mckenzie Rd Austin  TX  30.143322 -97.695722
# 3812          Fm 969 And Webberwood Way Webberville  TX  30.221458 -97.488937

# %%
#Skip element 3813 for unknown reasons
testAPI_one = testAPI.loc[3814:3820, :]

# %%
#coord = pd.DataFrame([])
for i, row in testAPI_one.iterrows():
    location = str(row['Address'] + " " + row["City"] + " " + row["State"])
    result = g.geocode(location)
    Latitude = float(result.latitude)
    Longitude =float(result.longitude)
    line = pd.Series([location, Latitude, Longitude])
    coord = coord.append(line, ignore_index = True)

# %%
#Error at 3813 and 4699 and 7967 and 8290
#3813 and 8290 removed
testAPI_two = testAPI.loc[8291:, :]

# %%
testAPI_two.head()
# Out:
#       Unnamed: 0 Animal ID      Name             DateTime  \
# 8291       71488   A770182       Kit  2018-04-16 10:40:00
# 8292       71500   A778568       NaN  2018-08-17 09:14:00
# 8293       71506   A777888       NaN  2018-08-05 10:56:00
# 8294       71535   A780720    *Bambi  2018-09-19 13:25:00
# 8295       71536   A783913  Angelina  2018-11-08 15:33:00
#
#                    MonthYear Intake Type Intake Condition Animal Type  \
# 8291  04/16/2018 10:40:00 AM       Stray           Normal         Cat
# 8292  08/17/2018 09:14:00 AM       Stray           Normal         Dog
# 8293  08/05/2018 10:56:00 AM       Stray           Normal         Dog
# 8294  09/19/2018 01:25:00 PM       Stray           Normal         Dog
# 8295  11/08/2018 03:33:00 PM       Stray           Normal         Cat
#
#      Sex upon Intake Age upon Intake                   Breed        Color  \
# 8291     Intact Male          1 year  Domestic Shorthair Mix  Brown Tabby
# ...

# %%
for i, row in testAPI_two.iterrows():
    location = str(row['Address'] + " " + row["City"] + " " + row["State"])
    result = g.geocode(location)
    Latitude = float(result.latitude)
    Longitude =float(result.longitude)
    line = pd.Series([location, Latitude, Longitude])
    coord = coord.append(line, ignore_index = True)

# %%
# Out:
# (11209, 3)

# %%
#need to drop error rows before merge

# %%
coord = coord.rename(columns={0: 'Address',1: 'Latitude',2: 'Longitude'})
coord.to_csv('Stray_LatLong_2018.csv')

# %%
coord.loc[4695: 4699, :]
# Out:
#                                                 Address   Latitude  Longitude
# 4695                         East 7Th Street Austin  TX  30.261742 -97.718719
# 4696  Bradshaw Road And River Plantation Drive Austi...  30.131738 -97.777456
# 4697                     400 Grove Boulevard Austin  TX  30.246073 -97.704983
# 4698                      1660 Rutland Drive Austin  TX  30.373952 -97.710912
# 4699                      1660 Rutland Drive Austin  TX  30.373952 -97.710912

# %%
modAPI.loc[4695: 4699, :]
# Out:
#       index  Unnamed: 0 Animal ID         Name             DateTime  \
# 4695   4696       39852   A767248          NaN  2018-02-25 16:17:00
# 4696   4697       39861   A774952    *Starling  2018-06-22 12:06:00
# 4697   4698       39864   A785507        Jolly  2018-12-04 08:37:00
# 4698   4699       39866   A768752  *Lil Spirit  2018-03-24 15:34:00
# 4699   4700       39876   A772651          NaN  2018-05-22 11:42:00
#
#                    MonthYear Intake Type Intake Condition Animal Type  \
# 4695  02/25/2018 04:17:00 PM       Stray           Normal         Dog
# 4696  06/22/2018 12:06:00 PM       Stray           Normal         Cat
# 4697  12/04/2018 08:37:00 AM       Stray           Normal         Dog
# 4698  03/24/2018 03:34:00 PM       Stray           Normal         Cat
# 4699  05/22/2018 11:42:00 AM       Stray           Normal         Dog
#
#      Sex upon Intake Age upon Intake                     Breed        Color  \
# ...

# %%
modAPI = testAPI

# %%
coordissue = coord.drop(coord.index[4699])

# %%
coordissue.loc[4695: 4700, :]
# Out:
#                                                 Address   Latitude  Longitude
# 4695                         East 7Th Street Austin  TX  30.261742 -97.718719
# 4696  Bradshaw Road And River Plantation Drive Austi...  30.131738 -97.777456
# 4697                     400 Grove Boulevard Austin  TX  30.246073 -97.704983
# 4698                      1660 Rutland Drive Austin  TX  30.373952 -97.710912
# 4700  North Interstate 35 And Park Plaza Drive Austi...  30.374752 -97.676441

# %%
#4699 had double entry
coordissue = coordissue.reset_index()

# %%
modAPI = modAPI.drop(modAPI.index[3813])
modAPI = modAPI.drop(modAPI.index[8289])

# %%
modAPI.loc[8287: 8292, :]
# Out:
#       Unnamed: 0 Animal ID Name             DateTime               MonthYear  \
# 8287       71455   A776429  NaN  2018-07-13 14:23:00  07/13/2018 02:23:00 PM
# 8288       71463   A774916  NaN  2018-06-21 22:36:00  06/21/2018 10:36:00 PM
# 8289       71470   A783219  NaN  2018-10-27 11:03:00  10/27/2018 11:03:00 AM
# 8291       71488   A770182  Kit  2018-04-16 10:40:00  04/16/2018 10:40:00 AM
# 8292       71500   A778568  NaN  2018-08-17 09:14:00  08/17/2018 09:14:00 AM
#
#      Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 8287       Stray           Normal         Cat     Intact Male         1 month
# 8288       Stray             Sick         Cat         Unknown         2 weeks
# 8289       Stray           Normal         Dog     Intact Male         3 weeks
# 8291       Stray           Normal         Cat     Intact Male          1 year
# 8292       Stray           Normal         Dog   Intact Female         1 month
#
# ...

# %%
modAPI = modAPI.reset_index()

# %%
modAPI.shape
# Out:
# (11208, 16)

# %%
coordissue.shape
# Out:
# (11208, 3)

# %%
coordissue = coordissue.drop('index', axis = 1)

# %%
result = pd.concat([modAPI, coordissue], axis = 1, join = 'inner')
result.to_csv('MergedStrayCatDog_LatLong_2018.csv')
