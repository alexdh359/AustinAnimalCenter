# %%
import numpy as np
import pandas as pd
recordsIn = pd.read_csv('Austin_Animal_Center_Intakes.csv', encoding='latin-1')
recordsOut = pd.read_csv('Austin_Animal_Center_Outcomes.csv', encoding='latin-1')

# %%
#look at Stray
recordsStrayIn = recordsIn[recordsIn["Intake Type"] == 'Stray']

# %%
recordsStrayIn.head(50)
# Out:
#     Unnamed: 0 Animal ID        Name                DateTime  \
# 0            0   A748291    *Madison  05/01/2017 02:26:00 PM
# 1            1   A750529         NaN  05/28/2017 01:22:00 PM
# 2            2   A730601         NaN  07/07/2016 12:11:00 PM
# 3            3   A748238         NaN  05/01/2017 10:53:00 AM
# 7            7   A676515        Rico  04/11/2014 08:45:00 AM
# 8            8   A679549    *Gilbert  05/22/2014 03:43:00 PM
# 9            9   A683798  Mustachala  07/21/2016 12:16:00 PM
# 11          11   A683656         NaN  07/13/2014 01:20:00 PM
# 12          12   A709749    *Janeane  08/12/2015 06:29:00 PM
# 13          13   A773634       Augie  06/03/2018 03:26:00 PM
# 15          15   A733551    *Phillip  08/23/2016 02:35:00 PM
# 16          16   A756485         NaN  08/20/2017 03:07:00 PM
# 17          17   A732960     *Alexis  08/15/2016 03:08:00 PM
# 18          18   A720597   *Franklin  02/12/2016 02:35:00 PM
# 19          19   A782291         NaN  10/13/2018 10:59:00 AM
# 20          20   A749535      *Bongo  05/16/2017 11:29:00 AM
# 21          21   A671219         NaN  01/21/2014 11:19:00 AM
# 23          23   A782085        Luna  10/10/2018 01:21:00 PM
# 24          24   A711377        Ruso  09/06/2015 09:26:00 AM
# 26          26   A727402      Babaji  05/21/2016 04:30:00 PM
# 27          27   A695702         Dbo  01/20/2015 04:44:00 PM
# 28          28   A763217     *Milton  12/05/2017 01:51:00 PM
# 29          29   A715806   *Samantha  11/10/2015 12:49:00 PM
# 31          31   A749579      *Jacob  05/16/2017 05:19:00 PM
# 32          32   A714255         NaN  10/20/2015 12:14:00 PM
# 33          33   A759224        Lola  09/29/2017 11:31:00 AM
# 35          35   A729190      *Messi  06/14/2016 02:42:00 PM
# 36          36   A673275      Prince  02/21/2014 12:22:00 PM
# 37          37   A761131       *Mary  10/29/2017 05:48:00 PM
# 38          38   A783925         NaN  11/08/2018 05:56:00 PM
# 39          39   A755135     *Minnie  07/29/2017 02:28:00 PM
# 40          40   A742653       Lilly  01/25/2017 03:22:00 PM
# 41          41   A559625        Rico  07/13/2017 03:18:00 PM
# 42          42   A737776         NaN  11/04/2016 12:09:00 PM
# 43          43   A683041         NaN  07/06/2014 12:37:00 PM
# 44          44   A678576    Han Solo  05/10/2014 01:27:00 PM
# 46          46   A768476     *Fialla  03/20/2018 10:57:00 AM
# 47          47   A656923        June  11/01/2015 01:52:00 PM
# 48          48   A776610        Ruby  07/16/2018 03:33:00 PM
# 49          49   A751501         NaN  06/09/2017 08:06:00 AM
# 50          50   A752501         NaN  06/23/2017 11:00:00 AM
# 52          52   A743830        Tank  02/17/2017 06:49:00 PM
# 55          55   A703167       *Chai  05/21/2015 11:02:00 AM
# 56          56   A677624     *Claire  04/27/2014 11:23:00 AM
# 57          57   A663489    Precious  12/17/2014 02:21:00 PM
# 60          60   A667415      Phoebe  11/17/2013 05:03:00 PM
# 61          61   A699075         NaN  03/22/2015 10:56:00 AM
# 62          62   A667225         NaN  11/14/2013 04:41:00 PM
# 63          63   A777688       *Rook  08/01/2018 01:11:00 PM
# 64          64   A754906         NaN  07/26/2017 01:50:00 PM
#
#                  MonthYear                                     Found Location  \
# 0   05/01/2017 02:26:00 PM  S Pleasant Valley Rd And E Riverside Dr in Aus...
# 1   05/28/2017 01:22:00 PM                    8312 North Ih 35 in Austin (TX)
# 2   07/07/2016 12:11:00 PM                       1109 Shady Ln in Austin (TX)
# 3   05/01/2017 10:53:00 AM     Airport Blvd And Oak Springs Dr in Austin (TX)
# 7   04/11/2014 08:45:00 AM                      615 E. Wonsley in Austin (TX)
# 8   05/22/2014 03:43:00 PM                      124 W Anderson in Austin (TX)
# 9   07/21/2016 12:16:00 PM                     3118 Windsor Rd in Austin (TX)
# 11  07/13/2014 01:20:00 PM                  8238 Research Blvd in Austin (TX)
# 12  08/12/2015 06:29:00 PM                     4800 Weletka Dr in Austin (TX)
# 13  06/03/2018 03:26:00 PM                     Braker And Ih35 in Austin (TX)
# 15  08/23/2016 02:35:00 PM                     183 And Cameron in Austin (TX)
# 16  08/20/2017 03:07:00 PM                     1020 Grove Blvd in Austin (TX)
# 17  08/15/2016 03:08:00 PM            6808 S Ih 35 Frontage Rd in Austin (TX)
# 18  02/12/2016 02:35:00 PM                    8413 Danville Dr in Austin (TX)
# 19  10/13/2018 10:59:00 AM          127 North Webberville Road in Travis (TX)
# 20  05/16/2017 11:29:00 AM            6607 S Ih 35 Frontage Rd in Austin (TX)
# 21  01/21/2014 11:19:00 AM               11602 Gunsmoke Circle in Austin (TX)
# 23  10/10/2018 01:21:00 PM      6405 South Ih 35 Frontage Road in Austin (TX)
# 24  09/06/2015 09:26:00 AM            Los Arbolos Neighborhood in Austin (TX)
# 26  05/21/2016 04:30:00 PM              Mopac & W Slaughter Ln in Austin (TX)
# 27  01/20/2015 04:44:00 PM                  28Th St And Salado in Austin (TX)
# 28  12/05/2017 01:51:00 PM          5002 Nuckols Crossing Road in Austin (TX)
# 29  11/10/2015 12:49:00 PM               1506 Thorneridge Road in Austin (TX)
# 31  05/16/2017 05:19:00 PM                        5305 Bolm Rd in Austin (TX)
# 32  10/20/2015 12:14:00 PM                  1830 W Rundberg Ln in Austin (TX)
# 33  09/29/2017 11:31:00 AM  View Point Drive And Nuckols Crossing in Austi...
# 35  06/14/2016 02:42:00 PM                       Johnny Morris in Austin (TX)
# 36  02/21/2014 12:22:00 PM                        9308 N Lamar in Austin (TX)
# 37  10/29/2017 05:48:00 PM                    6506 Decker Lane in Austin (TX)
# 38  11/08/2018 05:56:00 PM            2303 Wagon Grossing Path in Austin (TX)
# 39  07/29/2017 02:28:00 PM                         Highway 183 in Austin (TX)
# 40  01/25/2017 03:22:00 PM                          Bratton Ln in Austin (TX)
# 41  07/13/2017 03:18:00 PM           Old Manchaca Rd & Drew Ln in Austin (TX)
# 42  11/04/2016 12:09:00 PM           Patricia St And Pamela St in Austin (TX)
# 43  07/06/2014 12:37:00 PM                           1128 Spur in Austin (TX)
# 44  05/10/2014 01:27:00 PM              Ih 35 And Riverside Dr in Austin (TX)
# 46  03/20/2018 10:57:00 AM               22718 Big Sandy Drive in Travis (TX)
# 47  11/01/2015 01:52:00 PM                    12505 Rampart St in Austin (TX)
# 48  07/16/2018 03:33:00 PM                  815 W Slaughter Ln in Austin (TX)
# 49  06/09/2017 08:06:00 AM                 Us 290 & Blue Goose in Austin (TX)
# 50  06/23/2017 11:00:00 AM                     1735 Rutland Dr in Austin (TX)
# 52  02/17/2017 06:49:00 PM                 4502 Hudson Bend Rd in Travis (TX)
# 55  05/21/2015 11:02:00 AM                    704 Hyde Park Ct in Austin (TX)
# 56  04/27/2014 11:23:00 AM                         13096 N 183 in Austin (TX)
# 57  12/17/2014 02:21:00 PM                         Garland Ave in Austin (TX)
# 60  11/17/2013 05:03:00 PM                 2203 Singletree Ave in Austin (TX)
# 61  03/22/2015 10:56:00 AM                  E 9Th And San Saba in Austin (TX)
# 62  11/14/2013 04:41:00 PM                    11417 Trails End in Travis (TX)
# 63  08/01/2018 01:11:00 PM                 15010 Fm 1825 in Pflugerville (TX)
# 64  07/26/2017 01:50:00 PM                      1400 East 51St in Austin (TX)
#
#    Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0        Stray           Normal         Dog   Intact Female       10 months
# 1        Stray           Normal         Dog   Intact Female        5 months
# 2        Stray           Normal         Cat     Intact Male        7 months
# 3        Stray           Normal         Dog     Intact Male         3 years
# 7        Stray           Normal         Dog     Intact Male        2 months
# 8        Stray           Normal         Cat     Intact Male         1 month
# 9        Stray           Normal         Cat   Spayed Female         3 years
# 11       Stray           Normal         Cat     Intact Male        2 months
# 12       Stray           Normal         Cat   Intact Female          1 year
# 13       Stray           Normal         Dog     Intact Male        10 years
# 15       Stray           Normal         Cat     Intact Male         1 month
# 16       Stray           Normal         Cat   Intact Female         1 month
# 17       Stray           Normal         Cat   Intact Female        2 months
# 18       Stray          Injured         Dog     Intact Male         2 years
# 19       Stray           Normal         Dog   Intact Female         2 years
# 20       Stray           Normal         Dog     Intact Male         2 years
# 21       Stray           Normal         Cat     Intact Male          1 year
# 23       Stray           Normal         Dog   Intact Female         1 month
# 24       Stray           Normal         Dog     Intact Male        3 months
# 26       Stray           Normal         Cat     Intact Male         1 month
# 27       Stray           Normal         Dog     Intact Male          1 year
# 28       Stray           Normal         Dog   Neutered Male        8 months
# 29       Stray           Normal         Dog   Intact Female         2 years
# 31       Stray           Normal         Cat     Intact Male         3 weeks
# 32       Stray          Nursing         Cat     Intact Male         1 weeks
# 33       Stray           Normal         Dog   Intact Female        9 months
# 35       Stray           Normal         Cat     Intact Male         4 weeks
# 36       Stray           Normal         Dog     Intact Male         3 years
# 37       Stray           Normal         Dog   Intact Female         3 weeks
# 38       Stray           Normal         Dog   Intact Female          1 year
# 39       Stray           Normal         Dog   Intact Female        9 months
# 40       Stray           Normal         Dog   Spayed Female          1 year
# 41       Stray           Normal         Dog   Neutered Male         7 years
# 42       Stray           Normal         Dog   Intact Female       10 months
# 43       Stray           Normal         Cat   Intact Female         3 weeks
# 44       Stray           Normal         Dog     Intact Male         2 years
# 46       Stray           Normal         Dog   Intact Female         2 years
# 47       Stray           Normal         Dog   Spayed Female         3 years
# 48       Stray           Normal         Cat   Intact Female         1 month
# 49       Stray          Injured         Dog     Intact Male          1 year
# 50       Stray           Normal         Cat   Intact Female          1 week
# 52       Stray           Normal         Dog     Intact Male         9 years
# 55       Stray           Normal         Cat   Intact Female          1 year
# 56       Stray           Normal         Cat   Intact Female         1 month
# 57       Stray           Normal         Dog   Spayed Female         2 years
# 60       Stray           Normal         Dog   Spayed Female         5 years
# 61       Stray           Normal         Cat         Unknown          1 year
# 62       Stray          Injured         Dog   Intact Female         9 years
# 63       Stray           Normal         Dog     Intact Male          1 year
# 64       Stray           Normal         Cat     Intact Male         1 month
#
#                               Breed                Color
# 0                      Pit Bull Mix                Black
# 1           Miniature Schnauzer Mix          White/Cream
# 2            Domestic Shorthair Mix           Blue Tabby
# 3                  Bichon Frise Mix                White
# 7                      Pit Bull Mix          White/Brown
# 8            Domestic Shorthair Mix          Black/White
# 9          Domestic Medium Hair Mix          White/Black
# 11                     Snowshoe Mix           Lynx Point
# 12           Domestic Shorthair Mix               Calico
# 13                    Dachshund Mix                  Red
# 15           Domestic Shorthair Mix    Brown Tabby/White
# 16           Domestic Shorthair Mix           Blue Tabby
# 17           Domestic Shorthair Mix               Calico
# 18                     Pit Bull Mix                 Blue
# 19           Labrador Retriever Mix               Yellow
# 20                Border Collie Mix          Black/White
# 21                      Siamese Mix          Flame Point
# 23              Black Mouth Cur Mix          Brown/Black
# 24              Anatol Shepherd Mix            Brown/Tan
# 26           Domestic Shorthair Mix          Brown Tabby
# 27                     Pit Bull Mix  Brown Brindle/White
# 28           Labrador Retriever Mix  Black/Brown Brindle
# 29         Boxer/Labrador Retriever                Black
# 31           Domestic Shorthair Mix           Blue Tabby
# 32           Domestic Shorthair Mix                Black
# 33                    Dachshund Mix           Blue/White
# 35           Domestic Shorthair Mix          Brown Tabby
# 36                     Pit Bull Mix     Blue Tiger/White
# 37                     Pit Bull Mix          Black/White
# 38                         Pit Bull          White/Black
# 39                    Catahoula Mix      Chocolate/White
# 40            Yorkshire Terrier Mix          Brown/Black
# 41           Labrador Retriever Mix          Black/White
# 42            Yorkshire Terrier Mix          Black/Brown
# 43           Domestic Shorthair Mix                Black
# 44               Miniature Pinscher            Black/Tan
# 46           Smooth Fox Terrier Mix       White/Tricolor
# 47           Labrador Retriever Mix          Black/White
# 48           Domestic Shorthair Mix           Blue Tabby
# 49                     Pit Bull Mix           Fawn/White
# 50           Domestic Shorthair Mix          Brown Tabby
# 52            Queensland Heeler Mix            Blue Tick
# 55           Domestic Shorthair Mix                Black
# 56           Domestic Shorthair Mix                Black
# 57  Chihuahua Shorthair/Rat Terrier             Tricolor
# 60         Maltese/Miniature Poodle                White
# 61           Domestic Shorthair Mix                Black
# 62               Siberian Husky Mix                 Gray
# 63                     Pit Bull Mix           Blue/White
# 64            Domestic Longhair Mix           Blue Tabby

# %%
recordsStrayIn.shape
# Out:
# (67959, 13)

# %%
testAPI = recordsStrayIn[0:3]
testAPI
# Out:
#    Unnamed: 0 Animal ID      Name                DateTime  \
# 0           0   A748291  *Madison  05/01/2017 02:26:00 PM
# 1           1   A750529       NaN  05/28/2017 01:22:00 PM
# 2           2   A730601       NaN  07/07/2016 12:11:00 PM
#
#                 MonthYear                                     Found Location  \
# 0  05/01/2017 02:26:00 PM  S Pleasant Valley Rd And E Riverside Dr in Aus...
# 1  05/28/2017 01:22:00 PM                    8312 North Ih 35 in Austin (TX)
# 2  07/07/2016 12:11:00 PM                       1109 Shady Ln in Austin (TX)
#
#   Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0       Stray           Normal         Dog   Intact Female       10 months
# 1       Stray           Normal         Dog   Intact Female        5 months
# 2       Stray           Normal         Cat     Intact Male        7 months
#
#                      Breed        Color
# 0             Pit Bull Mix        Black
# 1  Miniature Schnauzer Mix  White/Cream
# 2   Domestic Shorthair Mix   Blue Tabby

# %%
new = testAPI["Found Location"].str.split(" in ", n = 1, expand = True)
new1 = new[1].str.split("(", n = 1, expand = True)
new1[1] = new1[1].str.replace(")", '')
testAPI["Address"] = new[0]
testAPI["City"] = new1[0]
testAPI["State"] = new1[1]
testAPI.drop(columns =["Found Location"], inplace = True)

testAPI
# Out:
# C:\Users\Alex Hilton\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Alex Hilton\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Alex Hilton\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Alex Hilton\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#    Unnamed: 0 Animal ID      Name                DateTime  \
# 0           0   A748291  *Madison  05/01/2017 02:26:00 PM
# 1           1   A750529       NaN  05/28/2017 01:22:00 PM
# 2           2   A730601       NaN  07/07/2016 12:11:00 PM
#
#                 MonthYear Intake Type Intake Condition Animal Type  \
# 0  05/01/2017 02:26:00 PM       Stray           Normal         Dog
# 1  05/28/2017 01:22:00 PM       Stray           Normal         Dog
# 2  07/07/2016 12:11:00 PM       Stray           Normal         Cat
#
#   Sex upon Intake Age upon Intake                    Breed        Color  \
# 0   Intact Female       10 months             Pit Bull Mix        Black
# 1   Intact Female        5 months  Miniature Schnauzer Mix  White/Cream
# 2     Intact Male        7 months   Domestic Shorthair Mix   Blue Tabby
#
#                                    Address     City State
# 0  S Pleasant Valley Rd And E Riverside Dr  Austin     TX
# 1                         8312 North Ih 35  Austin     TX
# 2                            1109 Shady Ln  Austin     TX

# %%
import geocoder
import folium
from geopy.geocoders import GoogleV3
from geopy import geocoders

# %%
geolocator = GoogleV3(api_key="AIzaSyBmJkT-Ytt6zPAmD-wpSzwxX6u2u3477I0")
g = geocoders.GoogleV3(api_key="AIzaSyBmJkT-Ytt6zPAmD-wpSzwxX6u2u3477I0")

# %%
coord = pd.DataFrame([])
for i, row in testAPI.iterrows():
    #Address = str(row["Address"])
    #City = str(row["City"])
    #State = str(row["State"])
    location = str(row['Address'] + " " + row["City"] + " " + row["State"])
    #print(location)
    result = g.geocode(location)
    Latitude = float(result.latitude)
    Longitude =float(result.longitude)
    line = pd.Series([location, Latitude, Longitude])
    coord = coord.append(line, ignore_index = True)

# %%
coord = coord.rename(columns={0: 'Address',1: 'Latitude',2: 'Longitude'})

# %%
result = pd.concat([testAPI, coord], axis = 1, join = 'inner')

# %%
result
# Out:
#    Unnamed: 0 Animal ID      Name                DateTime  \
# 0           0   A748291  *Madison  05/01/2017 02:26:00 PM
# 1           1   A750529       NaN  05/28/2017 01:22:00 PM
# 2           2   A730601       NaN  07/07/2016 12:11:00 PM
#
#                 MonthYear Intake Type Intake Condition Animal Type  \
# 0  05/01/2017 02:26:00 PM       Stray           Normal         Dog
# 1  05/28/2017 01:22:00 PM       Stray           Normal         Dog
# 2  07/07/2016 12:11:00 PM       Stray           Normal         Cat
#
#   Sex upon Intake Age upon Intake                    Breed        Color  \
# 0   Intact Female       10 months             Pit Bull Mix        Black
# 1   Intact Female        5 months  Miniature Schnauzer Mix  White/Cream
# 2     Intact Male        7 months   Domestic Shorthair Mix   Blue Tabby
#
#                                    Address     City State  \
# 0  S Pleasant Valley Rd And E Riverside Dr  Austin     TX
# 1                         8312 North Ih 35  Austin     TX
# 2                            1109 Shady Ln  Austin     TX
#
#                                              Address   Latitude  Longitude
# 0  S Pleasant Valley Rd And E Riverside Dr Austin...  30.234143 -97.722869
# 1                        8312 North Ih 35 Austin  TX  30.347044 -97.697098
# 2                           1109 Shady Ln Austin  TX  30.260440 -97.692502

# %%
latit = coord["Latitude"][1]
long = coord["Longitude"][1]
map_Animal = folium.Map(location=[latit, long], zoom_start=10)

for lat, lng in zip(coord['Latitude'], coord['Longitude']):
    #label = '{}, {}'.format()
    #label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        #popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_Animal)
map_Animal
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
